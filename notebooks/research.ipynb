# %% [markdown]
# # OctoFlow Research Notebook
# Exploring FlowScore sensitivity to whale spikes.

# %%
import json, numpy as np
from pathlib import Path
data = json.load(open('../data/samples/whales_SOL.json'))
amounts = [e['amount'] for e in data['events']]
np.mean(amounts), np.max(amounts)
